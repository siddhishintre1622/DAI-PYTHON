# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.rand(50)
y= np.random.rand(50)
colors = np.random.rand(50)
sizes = 1000 * np.random.rand(50)

plt.figure(figsize=(8,6))
plt.scatter(x,y, c=Example')
plt.xlabel('X Axis')colors, s=sizes, alpha=0.5, cmap='viridis')
plt.title('Scatter Plot 
plt.ylabel('Y Axis')
plt.colorbar()
plt.show()
